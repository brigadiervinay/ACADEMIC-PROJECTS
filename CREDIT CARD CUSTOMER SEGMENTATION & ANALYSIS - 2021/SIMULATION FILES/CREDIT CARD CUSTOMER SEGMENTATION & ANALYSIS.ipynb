# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
data = pd.read_csv('CC_GENERAL.csv')

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
# CUST_ID                             8950 non-null object
# BALANCE                             8950 non-null float64
# BALANCE_FREQUENCY                   8950 non-null float64
# PURCHASES                           8950 non-null float64
# ONEOFF_PURCHASES                    8950 non-null float64
# INSTALLMENTS_PURCHASES              8950 non-null float64
# CASH_ADVANCE                        8950 non-null float64
# PURCHASES_FREQUENCY                 8950 non-null float64
# ONEOFF_PURCHASES_FREQUENCY          8950 non-null float64
# PURCHASES_INSTALLMENTS_FREQUENCY    8950 non-null float64
# CASH_ADVANCE_FREQUENCY              8950 non-null float64
# CASH_ADVANCE_TRX                    8950 non-null int64
# PURCHASES_TRX                       8950 non-null int64
# CREDIT_LIMIT                        8949 non-null float64
# PAYMENTS                            8950 non-null float64
# MINIMUM_PAYMENTS                    8637 non-null float64
# PRC_FULL_PAYMENT                    8950 non-null float64
# TENURE                              8950 non-null int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
data.shape
# Out:
# (8950, 18)

# %%
data = data.drop(columns = ['CUST_ID'])        #REMOVING IRRELEVANT COLUMNS

# %%
def var_summary(x):
    return pd.Series([x.isnull().sum(), x.mean(), x.median(), x.quantile(0.99), x.max()], 
                  index=['MISSING VALUES','MEAN','MEDIAN','P99', 'MAX'])

num_summary=data.apply(lambda x: var_summary(x)).T
num_summary
# Out:
#                                   MISSING VALUES         MEAN       MEDIAN  \
# BALANCE                                      0.0  1564.474828   873.385231
# BALANCE_FREQUENCY                            0.0     0.877271     1.000000
# PURCHASES                                    0.0  1003.204834   361.280000
# ONEOFF_PURCHASES                             0.0   592.437371    38.000000
# INSTALLMENTS_PURCHASES                       0.0   411.067645    89.000000
# CASH_ADVANCE                                 0.0   978.871112     0.000000
# PURCHASES_FREQUENCY                          0.0     0.490351     0.500000
# ONEOFF_PURCHASES_FREQUENCY                   0.0     0.202458     0.083333
# PURCHASES_INSTALLMENTS_FREQUENCY             0.0     0.364437     0.166667
# CASH_ADVANCE_FREQUENCY                       0.0     0.135144     0.000000
# CASH_ADVANCE_TRX                             0.0     3.248827     0.000000
# PURCHASES_TRX                                0.0    14.709832     7.000000
# CREDIT_LIMIT                                 1.0  4494.449450  3000.000000
# PAYMENTS                                     0.0  1733.143852   856.901546
# MINIMUM_PAYMENTS                           313.0   864.206542   312.343947
# PRC_FULL_PAYMENT                             0.0     0.153715     0.000000
# TENURE                                       0.0    11.517318    12.000000
#
#                                            P99          MAX
# BALANCE                            9338.804814  19043.13856
# BALANCE_FREQUENCY                     1.000000      1.00000
# PURCHASES                          8977.290000  49039.57000
# ONEOFF_PURCHASES                   6689.898200  40761.25000
# INSTALLMENTS_PURCHASES             3886.240500  22500.00000
# CASH_ADVANCE                       9588.163357  47137.21176
# PURCHASES_FREQUENCY                   1.000000      1.00000
# ONEOFF_PURCHASES_FREQUENCY            1.000000      1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.000000      1.00000
# CASH_ADVANCE_FREQUENCY                0.833333      1.50000
# CASH_ADVANCE_TRX                     29.000000    123.00000
# PURCHASES_TRX                       116.510000    358.00000
# CREDIT_LIMIT                      17000.000000  30000.00000
# PAYMENTS                          13608.715541  50721.48336
# MINIMUM_PAYMENTS                   9034.098737  76406.20752
# PRC_FULL_PAYMENT                      1.000000      1.00000
# TENURE                               12.000000     12.00000

# %%
# replacing missing data with median
data.MINIMUM_PAYMENTS =data.MINIMUM_PAYMENTS.fillna(data.MINIMUM_PAYMENTS.median())
data.CREDIT_LIMIT =data.CREDIT_LIMIT.fillna(data.CREDIT_LIMIT.median())

# %%
# Outlier Treatment
def outlier_capping(x):
    x = x.clip_upper(x.quantile(0.99))
    x = x.clip_lower(x.quantile(0.01))
    return x

data = data.apply(lambda x: outlier_capping(x))
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: clip_upper(threshold) is deprecated, use clip(upper=threshold) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: clip_lower(threshold) is deprecated, use clip(lower=threshold) instead
#   after removing the cwd from sys.path.

# %%
# Data after missing and outlier treatment

def var_summary(x):
    return pd.Series([x.isnull().sum(), x.mean(), x.median(), x.quantile(0.99), x.max()], 
                  index=['MISSING VALUES','MEAN','MEDIAN','P99', 'MAX'])

num_summary=data.apply(lambda x: var_summary(x)).T
num_summary
# Out:
#                                   MISSING VALUES         MEAN       MEDIAN  \
# BALANCE                                      0.0  1541.046707   873.385231
# BALANCE_FREQUENCY                            0.0     0.878083     1.000000
# PURCHASES                                    0.0   936.229237   361.280000
# ONEOFF_PURCHASES                             0.0   536.493774    38.000000
# INSTALLMENTS_PURCHASES                       0.0   384.498368    89.000000
# CASH_ADVANCE                                 0.0   935.920972     0.000000
# PURCHASES_FREQUENCY                          0.0     0.490351     0.500000
# ONEOFF_PURCHASES_FREQUENCY                   0.0     0.202458     0.083333
# PURCHASES_INSTALLMENTS_FREQUENCY             0.0     0.364437     0.166667
# CASH_ADVANCE_FREQUENCY                       0.0     0.134017     0.000000
# CASH_ADVANCE_TRX                             0.0     3.079330     0.000000
# PURCHASES_TRX                                0.0    14.151385     7.000000
# CREDIT_LIMIT                                 0.0  4474.254540  3000.000000
# PAYMENTS                                     0.0  1649.420364   856.901546
# MINIMUM_PAYMENTS                             0.0   747.406471   312.343947
# PRC_FULL_PAYMENT                             0.0     0.153715     0.000000
# TENURE                                       0.0    11.517318    12.000000
#
#                                            P99           MAX
# BALANCE                            9337.094398   9338.804814
# BALANCE_FREQUENCY                     1.000000      1.000000
# PURCHASES                          8961.796200   8977.290000
# ONEOFF_PURCHASES                   6684.195482   6689.898200
# INSTALLMENTS_PURCHASES             3885.853155   3886.240500
# CASH_ADVANCE                       9584.005151   9588.163357
# PURCHASES_FREQUENCY                   1.000000      1.000000
# ONEOFF_PURCHASES_FREQUENCY            1.000000      1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.000000      1.000000
# CASH_ADVANCE_FREQUENCY                0.833333      0.833333
# CASH_ADVANCE_TRX                     29.000000     29.000000
# PURCHASES_TRX                       116.260100    116.510000
# CREDIT_LIMIT                      17000.000000  17000.000000
# PAYMENTS                          13586.255763  13608.715541
# MINIMUM_PAYMENTS                   8617.793812   8626.691541
# PRC_FULL_PAYMENT                      1.000000      1.000000
# TENURE                               12.000000     12.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
# BALANCE                             8950 non-null float64
# BALANCE_FREQUENCY                   8950 non-null float64
# PURCHASES                           8950 non-null float64
# ONEOFF_PURCHASES                    8950 non-null float64
# INSTALLMENTS_PURCHASES              8950 non-null float64
# CASH_ADVANCE                        8950 non-null float64
# PURCHASES_FREQUENCY                 8950 non-null float64
# ONEOFF_PURCHASES_FREQUENCY          8950 non-null float64
# PURCHASES_INSTALLMENTS_FREQUENCY    8950 non-null float64
# CASH_ADVANCE_FREQUENCY              8950 non-null float64
# CASH_ADVANCE_TRX                    8950 non-null int64
# PURCHASES_TRX                       8950 non-null float64
# CREDIT_LIMIT                        8950 non-null float64
# PAYMENTS                            8950 non-null float64
# MINIMUM_PAYMENTS                    8950 non-null float64
# PRC_FULL_PAYMENT                    8950 non-null float64
# TENURE                              8950 non-null int64
# dtypes: float64(15), int64(2)
# memory usage: 1.2 MB

# %%
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0            2.0        1000.0
# 1                0.250000                 4            0.0        7000.0
# 2                0.000000                 0           12.0        7500.0
# 3                0.083333                 1            1.0        7500.0
# 4                0.000000                 0            1.0        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        312.343947          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# ### Deriving Key Performance Indicators

# %% [markdown]
# #### 1.Monthly average purchase

# %%
data['Mon_av_PURCHASE'] = data.PURCHASES / data.TENURE

# %% [markdown]
# #### 2.Monthly cash Advance amount

# %%
data['Mon_cash_adv'] = data.CASH_ADVANCE / data.TENURE

# %% [markdown]
# #### 3.Purchase by type(on-off/installment)

# %%
data['Purchase_type_on_off'] = np.where(data.ONEOFF_PURCHASES>0,1,0)
data['Purchase_type_installment'] = np.where(data.INSTALLMENTS_PURCHASES>0,1,0)
data['Purchase_Type_both'] = np.where((data.Purchase_type_on_off + data.Purchase_type_installment) ==2,1,0 )

# %% [markdown]
# #### 4. Limit Usage

# %%
data['Limit_Usage'] = data.BALANCE / data.CREDIT_LIMIT

# %% [markdown]
# #### 5.Payment to minimum payment ratio

# %%
data['Ratio_payment_to_min_payment'] = data.PAYMENTS / data.MINIMUM_PAYMENTS

# %%
data.head(10)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
# 6   627.260806           1.000000    7091.01           6402.63
# 7  1823.652743           1.000000     436.20              0.00
# 8  1014.926473           1.000000     861.49            661.49
# 9   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
# 7                  436.20      0.000000             1.000000
# 8                  200.00      0.000000             0.333333
# 9                    0.00      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
# 7                    0.000000                          1.000000
# 8                    0.083333                          0.250000
# 9                    0.166667                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  ...  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 0                0.000000  ...        139.509787          0.000000      12
# 1                0.250000  ...       1072.340217          0.222222      12
# 2                0.000000  ...        627.284787          0.000000      12
# 3                0.083333  ...        312.343947          0.000000      12
# 4                0.000000  ...        244.791237          0.000000      12
# 5                0.000000  ...       2407.246035          0.000000      12
# 6                0.000000  ...        198.065894          1.000000      12
# 7                0.000000  ...        532.033990          0.000000      12
# 8                0.000000  ...        311.963409          0.000000      12
# 9                0.000000  ...        100.302262          0.000000      12
#
#    Mon_av_PURCHASE  Mon_cash_adv  Purchase_type_on_off  \
# 0         7.950000      0.000000                     0
# 1         0.000000    536.912124                     0
# 2        64.430833      0.000000                     1
# 3       124.916667     17.149001                     1
# 4         1.333333      0.000000                     1
# 5       111.106667      0.000000                     0
# 6       590.917500      0.000000                     1
# 7        36.350000      0.000000                     0
# 8        71.790833      0.000000                     1
# 9       106.800000      0.000000                     1
#
#    Purchase_type_installment  Purchase_Type_both  Limit_Usage  \
# 0                          1                   0     0.040901
# 1                          0                   0     0.457495
# 2                          0                   0     0.332687
# 3                          0                   0     0.222223
# 4                          0                   0     0.681429
# 5                          1                   0     1.005460
# 6                          1                   1     0.046464
# 7                          1                   0     0.792892
# 8                          1                   1     0.144989
# 9                          0                   0     0.013839
#
#    Ratio_payment_to_min_payment
# 0                      1.446508
# 1                      3.826241
# 2                      0.991682
# 3                      0.000000
# 4                      2.771075
# 5                      0.581601
# 6                     32.081820
# 7                      1.276357
# 8                      2.206280
# 9                     11.612605
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Standardizing data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data_scaled=sc.fit_transform(data)

# %%
data_scaled = pd.DataFrame(data_scaled)
data_scaled.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.762856 -0.255968 -0.551327 -0.489121 -0.427513 -0.527079 -0.806490
# 1  0.844867  0.132501 -0.613881 -0.489121 -0.568588  3.101370 -1.221758
# 2  0.485181  0.520970 -0.106917  0.215778 -0.568588 -0.527079  1.269843
# 3  0.063882 -1.032906  0.369006  0.877517 -0.568588 -0.411186 -1.014125
# 4 -0.367830  0.520970 -0.603389 -0.474534 -0.568588 -0.527079 -1.014125
#
#          7         8         9   ...        14        15       16        17  \
# 0 -0.678661 -0.707313 -0.685371  ... -0.493151 -0.525551  0.36068 -0.559583
# 1 -0.678661 -0.916995  0.593147  ...  0.263600  0.234227  0.36068 -0.620854
# 2  2.673451 -0.916995 -0.685371  ... -0.097448 -0.525551  0.36068 -0.124282
# 3 -0.399319 -0.916995 -0.259200  ... -0.352941 -0.525551  0.36068  0.341886
# 4 -0.399319 -0.916995 -0.685371  ... -0.407742 -0.525551  0.36068 -0.610578
#
#          18        19        20        21        22        23
# 0 -0.510509 -1.039436  0.881992 -0.670193 -0.979687 -0.273174
# 1  2.704783 -1.039436 -1.133797 -0.670193  0.205564 -0.113670
# 2 -0.510509  0.962060 -1.133797 -0.670193 -0.149529 -0.303659
# 3 -0.407813  0.962060 -1.133797 -0.670193 -0.463809 -0.370128
# 4 -0.510509  0.962060 -1.133797 -0.670193  0.842675 -0.184394
#
# [5 rows x 24 columns]

# %%
data_scaled.columns = data.columns
col_names = data_scaled.columns
data_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.762856          -0.255968  -0.551327         -0.489121
# 1  0.844867           0.132501  -0.613881         -0.489121
# 2  0.485181           0.520970  -0.106917          0.215778
# 3  0.063882          -1.032906   0.369006          0.877517
# 4 -0.367830           0.520970  -0.603389         -0.474534
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.427513     -0.527079            -0.806490
# 1               -0.568588      3.101370            -1.221758
# 2               -0.568588     -0.527079             1.269843
# 3               -0.568588     -0.411186            -1.014125
# 4               -0.568588     -0.527079            -1.014125
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.678661                         -0.707313
# 1                   -0.678661                         -0.916995
# 2                    2.673451                         -0.916995
# 3                   -0.399319                         -0.916995
# 4                   -0.399319                         -0.916995
#
#    CASH_ADVANCE_FREQUENCY  ...  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT   TENURE  \
# 0               -0.685371  ...         -0.493151         -0.525551  0.36068
# 1                0.593147  ...          0.263600          0.234227  0.36068
# 2               -0.685371  ...         -0.097448         -0.525551  0.36068
# 3               -0.259200  ...         -0.352941         -0.525551  0.36068
# 4               -0.685371  ...         -0.407742         -0.525551  0.36068
#
#    Mon_av_PURCHASE  Mon_cash_adv  Purchase_type_on_off  \
# 0        -0.559583     -0.510509             -1.039436
# 1        -0.620854      2.704783             -1.039436
# 2        -0.124282     -0.510509              0.962060
# 3         0.341886     -0.407813              0.962060
# 4        -0.610578     -0.510509              0.962060
#
#    Purchase_type_installment  Purchase_Type_both  Limit_Usage  \
# 0                   0.881992           -0.670193    -0.979687
# 1                  -1.133797           -0.670193     0.205564
# 2                  -1.133797           -0.670193    -0.149529
# 3                  -1.133797           -0.670193    -0.463809
# 4                  -1.133797           -0.670193     0.842675
#
#    Ratio_payment_to_min_payment
# 0                     -0.273174
# 1                     -0.113670
# 2                     -0.303659
# 3                     -0.370128
# 4                     -0.184394
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Dimension Reduction

# %%
from sklearn.decomposition import PCA

# %%
data_scaled.shape
# Out:
# (8950, 24)

# %%
pc = PCA(n_components=24)

# %%
pc.fit(data_scaled)

#The amount of variance that each PC explains
var= pc.explained_variance_ratio_

#Cumulative Variance explains
var1=np.cumsum(np.round(pc.explained_variance_ratio_, decimals=4)*100)

# %%
var1
# Out:
# array([ 28.71,  48.36,  57.17,  64.95,  70.5 ,  75.02,  78.9 ,  82.43,
#         85.43,  88.  ,  90.08,  92.12,  93.88,  95.25,  96.49,  97.5 ,
#         98.31,  98.86,  99.32,  99.71,  99.85,  99.93, 100.01, 100.03])

# %%
plt.plot(var1)

# %% [markdown]
# ### Since 8 factors are explaining more than 80 % variance we use 8 factors

# %%
pc_final=PCA(n_components=8).fit(data_scaled)

reduced_cr=pc_final.fit_transform(data_scaled)

# %%
pd.DataFrame(reduced_cr).head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.594557 -2.108983 -0.152200  0.147120  0.468670 -0.152426  0.051817
# 1 -2.688504  3.197300  1.028895  1.446832  0.653855 -0.722363 -0.231660
# 2  0.655865 -0.203372  0.763001 -2.370604 -0.618224 -0.782838 -0.457797
# 3 -0.731784 -0.405740  1.697448 -1.605318  0.523376 -0.443294 -1.073757
# 4 -1.842256 -0.968944  0.133155 -1.983891  0.046467  0.029464  0.712768
#
#           7
# 0  0.156417
# 1 -0.698814
# 2 -1.165876
# 3 -0.017964
# 4  0.144930

# %%
col_list=data_scaled.columns
col_list
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE', 'Mon_av_PURCHASE', 'Mon_cash_adv', 'Purchase_type_on_off',
#        'Purchase_type_installment', 'Purchase_Type_both', 'Limit_Usage',
#        'Ratio_payment_to_min_payment'],
#       dtype='object')

# %% [markdown]
# ### Creating Loading matrix

# %%
Loadings =  pd.DataFrame((pc_final.components_.T * np.sqrt(pc_final.explained_variance_)).T,columns=data_scaled.columns).T
Loadings.to_csv('Loadings.csv')

# %% [markdown]
# ### new variables

# %%
new_cols = ['PURCHASES','ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','CASH_ADVANCE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY',
             'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY','CASH_ADVANCE_TRX','PURCHASES_TRX','PAYMENTS','MINIMUM_PAYMENTS','TENURE',
             'Mon_av_PURCHASE','Purchase_type_on_off','Purchase_type_installment','Limit_Usage','Mon_cash_adv', 'Purchase_Type_both']

# %% [markdown]
# ### using reduced variables now

# %%
data_scaled = data_scaled[new_cols]

# %%
data_scaled.head()
# Out:
#    PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# 0  -0.551327         -0.489121               -0.427513     -0.527079
# 1  -0.613881         -0.489121               -0.568588      3.101370
# 2  -0.106917          0.215778               -0.568588     -0.527079
# 3   0.369006          0.877517               -0.568588     -0.411186
# 4  -0.603389         -0.474534               -0.568588     -0.527079
#
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0            -0.806490                   -0.678661
# 1            -1.221758                   -0.678661
# 2             1.269843                    2.673451
# 3            -1.014125                   -0.399319
# 4            -1.014125                   -0.399319
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                         -0.707313               -0.685371         -0.557505
# 1                         -0.916995                0.593147          0.166685
# 2                         -0.916995               -0.685371         -0.557505
# 3                         -0.916995               -0.259200         -0.376457
# 4                         -0.916995               -0.685371         -0.557505
#
#    PURCHASES_TRX  PAYMENTS  MINIMUM_PAYMENTS   TENURE  Mon_av_PURCHASE  \
# 0      -0.579714 -0.642945         -0.493151  0.36068        -0.559583
# 1      -0.675130  1.089747          0.263600  0.36068        -0.620854
# 2      -0.102638 -0.456289         -0.097448  0.36068        -0.124282
# 3      -0.627422 -0.732573         -0.352941  0.36068         0.341886
# 4      -0.627422 -0.431298         -0.407742  0.36068        -0.610578
#
#    Purchase_type_on_off  Purchase_type_installment  Limit_Usage  Mon_cash_adv  \
# 0             -1.039436                   0.881992    -0.979687     -0.510509
# 1             -1.039436                  -1.133797     0.205564      2.704783
# 2              0.962060                  -1.133797    -0.149529     -0.510509
# 3              0.962060                  -1.133797    -0.463809     -0.407813
# 4              0.962060                  -1.133797     0.842675     -0.510509
#
#    Purchase_Type_both
# 0           -0.670193
# 1           -0.670193
# 2           -0.670193
# 3           -0.670193
# 4           -0.670193

# %% [markdown]
# ### Clustering data using K Means algorithm

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# #### 3 Cluster Solution

# %%
km_3 = KMeans(n_clusters=3,random_state=123)
km_3.fit(reduced_cr)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=123, tol=0.0001, verbose=0)

# %%
pd.Series(km_3.labels_).value_counts()
# Out:
# 0    4712
# 2    2950
# 1    1288
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.scatter(reduced_cr[:,0], reduced_cr[:,1], c=km_3.labels_.astype(float))

# %% [markdown]
# ### Cluster 4,5,6,7,8 Solutions

# %%
#3 clusters
km_3 = KMeans(n_clusters=3,random_state=123).fit(reduced_cr)

# 4 clusters
km_4=KMeans(n_clusters=4,random_state=123).fit(reduced_cr)

# 5 clusters
km_5=KMeans(n_clusters=5,random_state=123).fit(reduced_cr)

# 6 clusters
km_6=KMeans(n_clusters=6,random_state=123).fit(reduced_cr)

# 7 clusters
km_7=KMeans(n_clusters=7,random_state=123).fit(reduced_cr)

# 8 clusters
km_8=KMeans(n_clusters=8,random_state=123).fit(reduced_cr)

# %%
data_scaled.head(10)
# Out:
#    PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# 0  -0.551327         -0.489121               -0.427513     -0.527079
# 1  -0.613881         -0.489121               -0.568588      3.101370
# 2  -0.106917          0.215778               -0.568588     -0.527079
# 3   0.369006          0.877517               -0.568588     -0.411186
# 4  -0.603389         -0.474534               -0.568588     -0.527079
# 5   0.260344         -0.489121                1.403039     -0.527079
# 6   4.035657          5.348155                0.449374     -0.527079
# 7  -0.327867         -0.489121                0.076455     -0.527079
# 8  -0.049006          0.113959               -0.272832     -0.527079
# 9   0.226458          0.679313               -0.568588     -0.527079
#
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0            -0.806490                   -0.678661
# 1            -1.221758                   -0.678661
# 2             1.269843                    2.673451
# 3            -1.014125                   -0.399319
# 4            -1.014125                   -0.399319
# 5             0.439310                   -0.678661
# 6             1.269843                    2.673451
# 7             1.269843                   -0.678661
# 8            -0.391225                   -0.399319
# 9            -0.806490                   -0.119974
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# 0                         -0.707313               -0.685371         -0.557505
# 1                         -0.916995                0.593147          0.166685
# 2                         -0.916995               -0.685371         -0.557505
# 3                         -0.916995               -0.259200         -0.376457
# 4                         -0.916995               -0.685371         -0.557505
# 5                          0.550784               -0.685371         -0.557505
# 6                          1.599199               -0.685371         -0.557505
# 7                          1.599199               -0.685371         -0.557505
# 8                         -0.287947               -0.685371         -0.557505
# 9                         -0.916995               -0.685371         -0.557505
#
#    PURCHASES_TRX  PAYMENTS  MINIMUM_PAYMENTS   TENURE  Mon_av_PURCHASE  \
# 0      -0.579714 -0.642945         -0.493151  0.36068        -0.559583
# 1      -0.675130  1.089747          0.263600  0.36068        -0.620854
# 2      -0.102638 -0.456289         -0.097448  0.36068        -0.124282
# 3      -0.627422 -0.732573         -0.352941  0.36068         0.341886
# 4      -0.627422 -0.431298         -0.407742  0.36068        -0.610578
# 5      -0.293468 -0.110752          1.346530  0.36068         0.235451
# 6       2.378162  2.089631         -0.445648  0.36068         3.933379
# 7      -0.102638 -0.430973         -0.174719  0.36068        -0.340702
# 8      -0.436591 -0.426881         -0.353249  0.36068        -0.067558
# 9      -0.532007 -0.215252         -0.524957  0.36068         0.202260
#
#    Purchase_type_on_off  Purchase_type_installment  Limit_Usage  Mon_cash_adv  \
# 0             -1.039436                   0.881992    -0.979687     -0.510509
# 1             -1.039436                  -1.133797     0.205564      2.704783
# 2              0.962060                  -1.133797    -0.149529     -0.510509
# 3              0.962060                  -1.133797    -0.463809     -0.407813
# 4              0.962060                  -1.133797     0.842675     -0.510509
# 5             -1.039436                   0.881992     1.764576     -0.510509
# 6              0.962060                   0.881992    -0.963860     -0.510509
# 7             -1.039436                   0.881992     1.159800     -0.510509
# 8              0.962060                   0.881992    -0.683545     -0.510509
# 9              0.962060                  -1.133797    -1.056681     -0.510509
#
#    Purchase_Type_both
# 0           -0.670193
# 1           -0.670193
# 2           -0.670193
# 3           -0.670193
# 4           -0.670193
# 5           -0.670193
# 6            1.492109
# 7           -0.670193
# 8            1.492109
# 9           -0.670193

# %% [markdown]
# ### Silhouette Coefficient to find optimum cluster solution

# %%
from sklearn import metrics
# calculate SC for K=3 through K=8
k_range = range(3, 9)
scores = []
for k in k_range:
    km = KMeans(n_clusters=k, random_state=1)
    km.fit(reduced_cr)
    scores.append(metrics.silhouette_score(reduced_cr, km.labels_))

# %%
# plot the results
plt.plot(k_range, scores)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Coefficient')
plt.grid(True)

# %% [markdown]
# ### calinski harabaz score to find optimum solution

# %%
# calculate for K=2 through K=8
from sklearn.metrics import calinski_harabaz_score
k_range = range(3, 9)
scores = []
for k in k_range:
    km = KMeans(n_clusters=k, random_state=100)
    km.fit_transform(reduced_cr)
    scores.append(calinski_harabaz_score(reduced_cr,km.labels_))

# %%
# plot the results
plt.plot(k_range, scores)
plt.xlabel('Number of clusters')
plt.ylabel('Calinski Harabaz Score')
plt.grid(True)

# %% [markdown]
# ### Elbow Analysis to find optimum solution

# %%
# calculate for K=2 through K=8
k_range = range(3, 9)
scores = []
for k in k_range:
    km = KMeans(n_clusters=k, random_state=1)
    km.fit_transform(reduced_cr)
    scores.append(km.inertia_)
scores
# Out:
# [112955.85149218464,
#  96532.16624485218,
#  85659.70492467766,
#  78456.96094915799,
#  73989.10776378892,
#  70376.48638611859]

# %%
plt.plot(k_range, scores)
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.grid(True)

# %% [markdown]
# ### Mean value of each variable group by Cluster- 5

# %%
C5=pd.concat([data_scaled[new_cols],pd.Series(km_5.labels_,name='cluster_5')],axis=1)

# %%
# Mean value of each variable group by Cluster- 6
cluster_5_output=C5.groupby('cluster_5').apply(lambda x: x[new_cols].mean()).T
cluster_5_output
# Out:
# cluster_5                                0         1         2         3  \
# PURCHASES                        -0.462265  0.254074 -0.276128  3.012542
# ONEOFF_PURCHASES                 -0.282353  0.232587 -0.487595  2.729737
# INSTALLMENTS_PURCHASES           -0.561976  0.218523  0.191511  2.044060
# CASH_ADVANCE                     -0.129964 -0.357770 -0.452512 -0.152517
# PURCHASES_FREQUENCY              -0.937849  0.734976  0.590229  1.112952
# ONEOFF_PURCHASES_FREQUENCY       -0.325475  0.741351 -0.674580  1.721481
# PURCHASES_INSTALLMENTS_FREQUENCY -0.897221  0.477258  0.818182  0.968225
# CASH_ADVANCE_FREQUENCY            0.071390 -0.345002 -0.560481 -0.274067
# CASH_ADVANCE_TRX                 -0.060997 -0.313168 -0.477069 -0.168803
# PURCHASES_TRX                    -0.575592  0.415736 -0.105496  2.474447
# PAYMENTS                         -0.290285 -0.079795 -0.394210  1.741290
# MINIMUM_PAYMENTS                 -0.116615 -0.167470 -0.168806  0.493423
# TENURE                           -0.090296  0.187098 -0.054577  0.271061
# Mon_av_PURCHASE                  -0.458953  0.248839 -0.271475  2.978354
# Purchase_type_on_off             -0.121241  0.961157 -1.015750  0.914727
# Purchase_type_installment        -1.045068  0.702872  0.881992  0.687904
# Limit_Usage                       0.252355 -0.189938 -0.471165 -0.115959
# Mon_cash_adv                     -0.123621 -0.355094 -0.435638 -0.164685
# Purchase_Type_both               -0.659617  1.298994 -0.644603  1.232779
#
# cluster_5                                4
# PURCHASES                        -0.352727
# ONEOFF_PURCHASES                 -0.264658
# INSTALLMENTS_PURCHASES           -0.343549
# CASH_ADVANCE                      2.103023
# PURCHASES_FREQUENCY              -0.582133
# ONEOFF_PURCHASES_FREQUENCY       -0.283378
# PURCHASES_INSTALLMENTS_FREQUENCY -0.515074
# CASH_ADVANCE_FREQUENCY            1.763687
# CASH_ADVANCE_TRX                  1.863096
# PURCHASES_TRX                    -0.389362
# PAYMENTS                          0.799066
# MINIMUM_PAYMENTS                  0.744907
# TENURE                           -0.179392
# Mon_av_PURCHASE                  -0.341015
# Purchase_type_on_off             -0.230036
# Purchase_type_installment        -0.524820
# Limit_Usage                       0.641768
# Mon_cash_adv                      2.052921
# Purchase_Type_both               -0.267087

# %% [markdown]
# ## Profiling

# %%
# Conactenating labels found through Kmeans with data 
data_scaled['cluster_3'] = km_3.labels_
data_scaled['cluster_4'] = km_4.labels_
data_scaled['cluster_5'] = km_5.labels_
data_scaled['cluster_6'] = km_6.labels_
data_scaled['cluster_7'] = km_7.labels_
data_scaled['cluster_8'] = km_8.labels_

# %%
size=pd.concat([pd.Series(data_scaled.cluster_3.size), pd.Series.sort_index(data_scaled.cluster_3.value_counts()), pd.Series.sort_index(data_scaled.cluster_4.value_counts()),
           pd.Series.sort_index(data_scaled.cluster_5.value_counts()), pd.Series.sort_index(data_scaled.cluster_6.value_counts()),
           pd.Series.sort_index(data_scaled.cluster_7.value_counts()), pd.Series.sort_index(data_scaled.cluster_8.value_counts())])

# %%
Seg_size=pd.DataFrame(size, columns=['Seg_size'])
Seg_Pct = pd.DataFrame(size*100/data_scaled.cluster_3.size, columns=['Seg_Pct'])
Seg_size.T
Seg_Pct.T
# Out:
#              0          0          1          2          0          1  \
# Seg_Pct  100.0  52.648045  14.391061  32.960894  37.675978  10.268156
#
#                  2          3          0         1  ...          5          6  \
# Seg_Pct  39.441341  12.614525  34.268156  24.77095  ...  14.547486  18.446927
#
#                 0          1         2          3          4         5  \
# Seg_Pct  3.061453  21.541899  9.318436  11.139665  19.106145  8.681564
#
#                  6          7
# Seg_Pct  16.670391  10.480447
#
# [1 rows x 34 columns]

# %%
# Mean value gives a good indication of the distribution of data. So we are finding mean value for each variable for each cluster
Profling_output = pd.concat([data_scaled.apply(lambda x: x.mean()).T, data_scaled.groupby('cluster_3').apply(lambda x: x.mean()).T, data_scaled.groupby('cluster_4').apply(lambda x: x.mean()).T,
          data_scaled.groupby('cluster_5').apply(lambda x: x.mean()).T, data_scaled.groupby('cluster_6').apply(lambda x: x.mean()).T,
          data_scaled.groupby('cluster_7').apply(lambda x: x.mean()).T, data_scaled.groupby('cluster_8').apply(lambda x: x.mean()).T], axis=1)

Profling_output_final=pd.concat([Seg_size.T, Seg_Pct.T, Profling_output], axis=0)
#Profling_output_final.columns = ['Seg_' + str(i) for i in Profling_output_final.columns]
Profling_output_final.columns = ['Overall', 'KM3_1', 'KM3_2', 'KM3_3',
                                'KM4_1', 'KM4_2', 'KM4_3', 'KM4_4',
                                'KM5_1', 'KM5_2', 'KM5_3', 'KM5_4', 'KM5_5',
                                'KM6_1', 'KM6_2', 'KM6_3', 'KM6_4', 'KM6_5','KM6_6',
                                'KM7_1', 'KM7_2', 'KM7_3', 'KM7_4', 'KM7_5','KM7_6','KM7_7',
                                'KM8_1', 'KM8_2', 'KM8_3', 'KM8_4', 'KM8_5','KM8_6','KM8_7','KM8_8',]

# %%
Profling_output_final.to_csv('Profiling_output5.csv')

# %% [markdown]
# ### Based on Silhoutee coeficcient and Profiling we choose 5 cluster Solution

# %% [markdown]
# #### Cluster plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(reduced_cr[:,0], reduced_cr[:,1], c=km_5.labels_.astype(float))
